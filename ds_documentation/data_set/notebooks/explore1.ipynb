# %%
import numpy as np
import scipy
import pandas as pd
import math
import random
import sklearn
from nltk.corpus import stopwords
from scipy.sparse import csr_matrix
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse.linalg import svds
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("../pet-set.xlsx")

# %%
df.head(3)
# Out:
#    How old is your cat (years)?  How long have you owned your cat (years)?  \
# 0                             6                                          6
# 1                             2                                          1
# 2                             5                                          5
#
#   Is your cat male or female? Where did you get your cat from?  \
# 0                        Male           Other (please specify)
# 1                      Female                  Rehoming centre
# 2                        Male                 Friend/neighbour
#
#   Other (please specify) Is your cat neutered?   What breed is your cat?  \
# 0           Knew his mum                   Yes  Domestic short/long hair
# 1                    NaN                   Yes  Domestic short/long hair
# 2                    NaN                   Yes  Domestic short/long hair
#
#   Other (please specify).1 Does your cat have access to the outdoors?  \
# 0                      NaN                                        Yes
# 1                      NaN                                        Yes
# 2                      NaN                                         No
#
#   If yes, does your cat have constant access, or is this restricted in some way (i.e. the cat is kept in at night or is only let out when someone is home)  \
# 0                                    Constant access
# 1                                  Restricted access
# 2                                                NaN
#
#    ... i see myself as someone who...Prefers work that is routine  \
# 0  ...                                  Disagree a little
# 1  ...                                     Agree strongly
# 2  ...                                                NaN
#
#   i see myself as someone who...Is outgoing, sociable  \
# 0                                     Agree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
#
#   i see myself as someone who...Is sometimes rude to others  \
# 0                                  Disagree strongly
# 1                         Neither agree nor disagree
# 2                                                NaN
#
#   i see myself as someone who...Makes plans and follows through with them  \
# 0                                  Disagree a little
# 1                                     Agree strongly
# 2                                                NaN
#
#   i see myself as someone who...Gets easily nervous  \
# 0                                    Agree a little
# 1                                    Agree strongly
# 2                                               NaN
#
#   i see myself as someone who...Likes to reflect and play with ideas  \
# 0                                  Disagree a little
# 1                                     Agree a little
# 2                                                NaN
#
#   i see myself as someone who...Has few artistic interests  \
# 0                                  Disagree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
#
#   i see myself as someone who...Likes to cooperate with others  \
# 0                                     Agree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
#
#   i see myself as someone who...Is easily distracted  \
# 0                                     Agree strongly
# 1                                  Disagree strongly
# 2                                                NaN
#
#   i see myself as someone who...Is sophisticated in art, music or literature
# 0                                     Agree a little
# 1                                     Agree strongly
# 2                                                NaN
#
# [3 rows x 105 columns]

# %%
# Overview of variables showing satisfaction level
print(df['My cat has met all my expectations'].value_counts())
print(df['I am happy with my cat'].value_counts())
print(df['I feel my cat is happy living with me'].value_counts())
print(df['I have considered relinquishing or rehoming this cat to someone else'].value_counts())
# Out:
# Strongly agree                2156
# Agree                          722
# Neither agree nor disagree     272
# Disagree                        86
# Strongly disagree               12
# Name: My cat has met all my expectations, dtype: int64
# Strongly agree                2794
# Agree                          395
# Neither agree nor disagree      39
# Disagree                        16
# Strongly disagree                4
# Name: I am happy with my cat, dtype: int64
# Strongly agree                2555
# Agree                          627
# Neither agree nor disagree      56
# Disagree                         7
# Strongly disagree                3
# Name: I feel my cat is happy living with me, dtype: int64
# Strongly disagree             2982
# Disagree                       169
# Agree                           57
# Neither agree nor disagree      33
# Strongly agree                   7
# Name: I have considered relinquishing or rehoming this cat to someone else, dtype: int64

# %%
# replacing strings with numerical values
df['expectations'] = df['My cat has met all my expectations'].replace({'Strongly agree': 5, 'Agree': 4, 'Neither agree nor disagree': 3, 'Disagree': 2, 'Strongly disagree': 1})
df['happy_owner'] = df['I am happy with my cat'].replace({'Strongly agree': 5, 'Agree': 4, 'Neither agree nor disagree': 3, 'Disagree': 2, 'Strongly disagree': 1})
df['happy_cat'] = df['I feel my cat is happy living with me'].replace({'Strongly agree': 5, 'Agree': 4, 'Neither agree nor disagree': 3, 'Disagree': 2, 'Strongly disagree': 1})
df['rehome'] = df['I have considered relinquishing or rehoming this cat to someone else'].replace({'Strongly agree': 1, 'Agree': 2, 'Neither agree nor disagree': 3, 'Disagree': 4, 'Strongly disagree': 5})

# %% [markdown]
# ### variable discribing the satisfaction level, might be transformed to percentage but unnecessary now

# %%
df['satisf_level'] = (df['expectations'] + df['happy_owner'] + df['happy_cat'] + df['rehome'])
df['satisf_level'].describe()

# %%
df['satisf_level'].value_counts()
# Out:
# 20.0    1940
# 19.0     491
# 18.0     286
# 17.0     250
# 16.0     133
# 15.0      62
# 14.0      38
# 13.0      13
# 12.0      12
# 11.0       8
# 10.0       5
# 8.0        5
# 9.0        2
# 7.0        2
# 5.0        1
# Name: satisf_level, dtype: int64

# %%
#df['rehome'].value_counts().sort_index()
#df['happy_owner'].value_counts().sort_index()
#df['happy_cat'].value_counts().sort_index()
#df['expectations'].value_counts().sort_index()

# %% [markdown]
# # Owners

# %%
# slice with owners data
owners = df.iloc[:, 58:]

# %%
owners.shape
# Out:
# (3331, 52)

# %%
owners = owners.dropna()

# %%
owners.shape
# Out:
# (3164, 53)

# %%
#creating the variable with owners ids from indexes, 30000 is just do make it distinguisable from cats ids
owners['id'] = owners.index
owners['owner_id'] = owners['id'].apply(lambda x: 30000 + x)
owners.drop('id', axis = 1, inplace = True)

# %%
owners.head()
# Out:
#    Gender    Age  \
# 0  Female  25-34
# 1  Female  25-34
# 3  Female  18-24
# 4  Female  25-34
# 5  Female  45-54
#
#    How many other cats live in the household (not including the cat you have described)  \
# 0                                                2.0
# 1                                                0.0
# 3                                                1.0
# 4                                                3.0
# 5                                                2.0
#
#   I see myself as someone who.....  \
# 0                   Agree a little
# 1                   Agree a little
# 3                   Agree a little
# 4                Disagree a little
# 5       Neither agree nor disagree
#
#   I see myself as someone who.....Tends to find fault with others  \
# 0                                     Agree a little
# 1                                     Agree a little
# 3                                     Agree a little
# 4                                     Agree a little
# 5                         Neither agree nor disagree
#
#   I see myself as someone who.....Does a thorough job  \
# 0                                     Agree a little
# 1                                     Agree strongly
# 3                         Neither agree nor disagree
# 4                                     Agree a little
# 5                                     Agree a little
#
#   I see myself as someone who.....Is depressed, blue  \
# 0                                     Agree a little
# 1                                  Disagree a little
# 3                                     Agree strongly
# 4                                  Disagree a little
# 5                                     Agree a little
#
#   I see myself as someone who.....Is original, comes up with new ideas  \
# 0                                  Disagree a little
# 1                                     Agree a little
# 3                                     Agree a little
# 4                         Neither agree nor disagree
# 5                                     Agree a little
#
#   I see myself as someone who.....Is reserved  \
# 0                              Agree a little
# 1                              Agree strongly
# 3                              Agree a little
# 4                              Agree a little
# 5                  Neither agree nor disagree
#
#   I see myself as someone who.....Is helpful and unselfish with others  ...  \
# 0                                     Agree strongly                    ...
# 1                                     Agree a little                    ...
# 3                                     Agree a little                    ...
# 4                                     Agree a little                    ...
# 5                                     Agree a little                    ...
#
#   i see myself as someone who...Has few artistic interests  \
# 0                                  Disagree a little
# 1                         Neither agree nor disagree
# 3                         Neither agree nor disagree
# 4                                  Disagree a little
# 5                         Neither agree nor disagree
#
#   i see myself as someone who...Likes to cooperate with others  \
# 0                                     Agree a little
# 1                         Neither agree nor disagree
# 3                         Neither agree nor disagree
# 4                                     Agree a little
# 5                         Neither agree nor disagree
#
#   i see myself as someone who...Is easily distracted  \
# 0                                     Agree strongly
# 1                                  Disagree strongly
# 3                                     Agree a little
# 4                                     Agree a little
# 5                         Neither agree nor disagree
#
#   i see myself as someone who...Is sophisticated in art, music or literature  \
# 0                                     Agree a little
# 1                                     Agree strongly
# 3                                  Disagree strongly
# 4                         Neither agree nor disagree
# 5                         Neither agree nor disagree
#
#   expectations happy_owner happy_cat rehome satisf_level owner_id
# 0          5.0         5.0       5.0    5.0         20.0    30000
# 1          5.0         5.0       5.0    5.0         20.0    30001
# 3          5.0         5.0       5.0    5.0         20.0    30003
# 4          5.0         5.0       5.0    5.0         20.0    30004
# 5          5.0         5.0       5.0    5.0         20.0    30005
#
# [5 rows x 53 columns]

# %% [markdown]
# # Cats

# %% [markdown]
# Almost the same here for cats

# %%
cats = df.iloc[:, 0:53]

# %%
cats.shape
# Out:
# (3331, 53)

# %%
# identifying the variables with many NaN values to drop them
cats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3331 entries, 0 to 3330
# Data columns (total 53 columns):
#  #   Column                                                                                                                                                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                 --------------  -----
#  0   How old is your cat (years)?                                                                                                                                                                                           3331 non-null   int64
#  1   How long have you owned your cat (years)?                                                                                                                                                                              3331 non-null   int64
#  2   Is your cat male or female?                                                                                                                                                                                            3331 non-null   object
#  3   Where did you get your cat from?                                                                                                                                                                                       3331 non-null   object
#  4   Other (please specify)                                                                                                                                                                                                 1074 non-null   object
#  5   Is your cat neutered?                                                                                                                                                                                                  3331 non-null   object
#  6   What breed is your cat?                                                                                                                                                                                                3331 non-null   object
#  7   Other (please specify).1                                                                                                                                                                                               620 non-null    object
#  8   Does your cat have access to the outdoors?                                                                                                                                                                             3331 non-null   object
#  9   If yes, does your cat have constant access, or is this restricted in some way (i.e. the cat is kept in at night or is only let out when someone is home)                                                               2456 non-null   object
#  10  Does your cat have a litter tray?                                                                                                                                                                                      3331 non-null   object
#  11  Does your cat have any existing medical conditions?                                                                                                                                                                    3331 non-null   object
#  12  If yes, what condition does he/she suffer from?                                                                                                                                                                        762 non-null    object
#  13  Was this condition present before you acquired your cat?                                                                                                                                                               916 non-null    object
#  14  Does your cat display any behavioural problems                                                                                                                                                                         3331 non-null   object
#  15  If yes, what behavioural problem does he/she display?                                                                                                                                                                  646 non-null    object
#  16  Was this problem present before you acquired your cat?                                                                                                                                                                 807 non-null    object
#  17  Does your cat suffer from a urinary tract infection (e.g. cystitis)?                                                                                                                                                   3331 non-null   object
#  18  Does your cat urinate inside the house in a location other than the litter tray?                                                                                                                                       3331 non-null   object
#  19  Does your cat spray urine on any vertical surfaces (e.g. curtains, kitchen, cabinets, doors, walls)?                                                                                                                   3331 non-null   object
#  20  Does your cat defecate inside the house in a location other than the litter tray?                                                                                                                                      3331 non-null   object
#  21  Does your cat vomit?                                                                                                                                                                                                   3331 non-null   object
#  22  Does your cat suffer from diarrhoea?                                                                                                                                                                                   3331 non-null   object
#  23  Does your cat suffer from constipation?                                                                                                                                                                                3331 non-null   object
#  24  How would you describe your cat's weight?                                                                                                                                                                              3331 non-null   object
#  25  What is the condition of your cat's coat (1-poor condition - 5-excellent condition)                                                                                                                                    3331 non-null   object
#  26  My cat is keen to explore new things in his/her environment                                                                                                                                                            3331 non-null   object
#  27  My cat is playful                                                                                                                                                                                                      3331 non-null   object
#  28  My cat is vocal when around people                                                                                                                                                                                     3331 non-null   object
#  29  My cat behaves aggressively (i.e. growls, hisses, bites, swipes with claws) towards me when I perform routine health procedures (such as grooming/carrying out health checks, or when administering medication, etc.)  3331 non-null   object
#  30  My cat tries to avoid me when I try to encourage interactions (i.e. when I call his/her name in a friendly voice, when I make kissing noises, or crouch down and offer it my fingers etc.)                             3331 non-null   object
#  31  My cat tries to avoid me when I go to stroke him/her or tickle his/her chin/cheeks                                                                                                                                     3331 non-null   object
#  32  When I initiate contact or interaction with my cat, he/she doesn't move away but it is quiet and not very responsive towards me (i.e. it doesn't purr or rub up against me)                                            3331 non-null   object
#  33  My cat behaves aggressively (i.e. growls, hisses, bites and swipes with claws) towards me when I stroke him/her                                                                                                        3331 non-null   object
#  34  My cat will come and say "hello" and approach me (i.e. the cat will approach and make physical contact with me), but will then wander off or move away shortly afterwards rather than staying for a long fuss          3331 non-null   object
#  35  My cat comes and asks me for attention and initiates contact with me (e.g. the cat comes and sits on my knee, or rubs up against me and around me, in order to receive fuss/strokes/chin/cheek tickles)                3331 non-null   object
#  36  My cat gets carried away during play, which has led me to being bitten or swiped                                                                                                                                       3331 non-null   object
#  37  I avoid stroking or handling my cat because I feel that he/she doesn't want me to                                                                                                                                      3331 non-null   object
#  38  I avoid stroking my cat because I think he/she will behave aggressively towards me (i.e. growl, hiss, bite, swipe with claws)                                                                                          3331 non-null   object
#  39  My cat seems angry around me                                                                                                                                                                                           3331 non-null   object
#  40  My cat is more keen to interact with and be near me when I have food/treats                                                                                                                                            3331 non-null   object
#  41  My cat is comfortable being picked up                                                                                                                                                                                  3259 non-null   object
#  42  My cat is timid                                                                                                                                                                                                        3259 non-null   object
#  43  My cat is quick to settle and to adapt to change                                                                                                                                                                       3259 non-null   object
#  44  My cat would prefer to be left alone, rather than be with people                                                                                                                                                       3259 non-null   object
#  45  My cat likes being stroked                                                                                                                                                                                             3259 non-null   object
#  46  My cat is very tolerant to being handled                                                                                                                                                                               3259 non-null   object
#  47  If my cat could choose, it would prefer to have a bowl of food rather than interaction with me                                                                                                                         3259 non-null   object
#  48  My cat has negatively changed the way he/she interacts with me since I first acquired him/her (e.g. has become more fearful, behaves aggressively, is less friendly)                                                   3259 non-null   object
#  49  My cat has positively changed in the way he/she interacts with me since I first acquired him/her (e.g. has become less fearful, behaves less aggressively, is more friendly)                                           3259 non-null   object
#  50  My cat behaves differently with strangers than he/she does with me                                                                                                                                                     3259 non-null   object
#  51  My cat behaves differently with me than he/she does with other (human) members of the household                                                                                                                        3259 non-null   object
#  52  My cat is friendly                                                                                                                                                                                                     3259 non-null   object
# dtypes: int64(2), object(51)
# memory usage: 1.3+ MB

# %%
#dropping the variables with too many NaN
cats = cats.drop(cats.columns[[4, 7, 9, 12, 13, 15, 16]], axis = 1)

# %%
cats = cats.dropna()
cats.shape
# Out:
# (3259, 47)

# %%
# IDs for cats
cats['id'] = cats.index
cats['cat_id'] = cats['id'].apply(lambda x: 20000 + x)
cats.drop('id', axis = 1, inplace = True)
cats.head()
# Out:
#    How old is your cat (years)?  How long have you owned your cat (years)?  \
# 0                             6                                          6
# 1                             2                                          1
# 2                             5                                          5
# 3                             4                                          4
# 4                             3                                          3
#
#   Is your cat male or female? Where did you get your cat from?  \
# 0                        Male           Other (please specify)
# 1                      Female                  Rehoming centre
# 2                        Male                 Friend/neighbour
# 3                      Female                 Friend/neighbour
# 4                      Female           Other (please specify)
#
#   Is your cat neutered?   What breed is your cat?  \
# 0                   Yes  Domestic short/long hair
# 1                   Yes  Domestic short/long hair
# 2                   Yes  Domestic short/long hair
# 3                   Yes  Domestic short/long hair
# 4                   Yes  Domestic short/long hair
#
#   Does your cat have access to the outdoors?  \
# 0                                        Yes
# 1                                        Yes
# 2                                         No
# 3                                        Yes
# 4                                        Yes
#
#   Does your cat have a litter tray?  \
# 0                                No
# 1                               Yes
# 2                               Yes
# 3                               Yes
# 4                               Yes
#
#   Does your cat have any existing medical conditions?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Does your cat display any behavioural problems  ...  \
# 0                                             No  ...
# 1                                             No  ...
# 2                                             No  ...
# 3                                             No  ...
# 4                                             No  ...
#
#   My cat would prefer to be left alone, rather than be with people  \
# 0                                           Disagree
# 1                         Neither agree nor disagree
# 2                         Neither agree nor disagree
# 3                                           Disagree
# 4                         Neither agree nor disagree
#
#    My cat likes being stroked My cat is very tolerant to being handled  \
# 0                       Agree               Neither agree nor disagree
# 1                       Agree               Neither agree nor disagree
# 2  Neither agree nor disagree                                 Disagree
# 3              Strongly agree                                    Agree
# 4                       Agree               Neither agree nor disagree
#
#   If my cat could choose, it would prefer to have a bowl of food rather than interaction with me  \
# 0                                              Agree
# 1                         Neither agree nor disagree
# 2                                              Agree
# 3                         Neither agree nor disagree
# 4                                              Agree
#
#   My cat has negatively changed the way he/she interacts with me since I first acquired him/her (e.g. has become more fearful, behaves aggressively, is less friendly)  \
# 0                                     Strongly agree
# 1                         Neither agree nor disagree
# 2                                           Disagree
# 3                                  Strongly disagree
# 4                                  Strongly disagree
#
#   My cat has positively changed in the way he/she interacts with me since I first acquired him/her (e.g. has become less fearful, behaves less aggressively, is more friendly)  \
# 0                         Neither agree nor disagree
# 1                         Neither agree nor disagree
# 2                                              Agree
# 3                                     Strongly agree
# 4                                     Strongly agree
#
#   My cat behaves differently with strangers than he/she does with me  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#   My cat behaves differently with me than he/she does with other (human) members of the household  \
# 0                                           Disagree
# 1                         Neither agree nor disagree
# 2                         Neither agree nor disagree
# 3                                              Agree
# 4                                              Agree
#
#            My cat is friendly cat_id
# 0                       Agree  20000
# 1              Strongly agree  20001
# 2  Neither agree nor disagree  20002
# 3                       Agree  20003
# 4                       Agree  20004
#
# [5 rows x 47 columns]

# %%
# indexed dataset with ids for cats and owners. Some owners don't have id, if there are NaN values.
df_i = cats.join(owners)
df_i.head()
# Out:
#    How old is your cat (years)?  How long have you owned your cat (years)?  \
# 0                             6                                          6
# 1                             2                                          1
# 2                             5                                          5
# 3                             4                                          4
# 4                             3                                          3
#
#   Is your cat male or female? Where did you get your cat from?  \
# 0                        Male           Other (please specify)
# 1                      Female                  Rehoming centre
# 2                        Male                 Friend/neighbour
# 3                      Female                 Friend/neighbour
# 4                      Female           Other (please specify)
#
#   Is your cat neutered?   What breed is your cat?  \
# 0                   Yes  Domestic short/long hair
# 1                   Yes  Domestic short/long hair
# 2                   Yes  Domestic short/long hair
# 3                   Yes  Domestic short/long hair
# 4                   Yes  Domestic short/long hair
#
#   Does your cat have access to the outdoors?  \
# 0                                        Yes
# 1                                        Yes
# 2                                         No
# 3                                        Yes
# 4                                        Yes
#
#   Does your cat have a litter tray?  \
# 0                                No
# 1                               Yes
# 2                               Yes
# 3                               Yes
# 4                               Yes
#
#   Does your cat have any existing medical conditions?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Does your cat display any behavioural problems  ...  \
# 0                                             No  ...
# 1                                             No  ...
# 2                                             No  ...
# 3                                             No  ...
# 4                                             No  ...
#
#   i see myself as someone who...Has few artistic interests  \
# 0                                  Disagree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                  Disagree a little
#
#   i see myself as someone who...Likes to cooperate with others  \
# 0                                     Agree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                     Agree a little
#
#   i see myself as someone who...Is easily distracted  \
# 0                                     Agree strongly
# 1                                  Disagree strongly
# 2                                                NaN
# 3                                     Agree a little
# 4                                     Agree a little
#
#   i see myself as someone who...Is sophisticated in art, music or literature  \
# 0                                     Agree a little
# 1                                     Agree strongly
# 2                                                NaN
# 3                                  Disagree strongly
# 4                         Neither agree nor disagree
#
#   expectations happy_owner happy_cat rehome satisf_level owner_id
# 0          5.0         5.0       5.0    5.0         20.0  30000.0
# 1          5.0         5.0       5.0    5.0         20.0  30001.0
# 2          NaN         NaN       NaN    NaN          NaN      NaN
# 3          5.0         5.0       5.0    5.0         20.0  30003.0
# 4          5.0         5.0       5.0    5.0         20.0  30004.0
#
# [5 rows x 100 columns]

# %%
# dropping rows with NaN values
df_i = df_i.dropna()
df_i.shape
# Out:
# (3164, 100)

# %% [markdown]
# # Split

# %%
train_df, test_df = train_test_split(df_i,
                                   test_size=0.20,
                                   random_state=42)
print('# Train set: %d' % len(train_df))
print('# Test set: %d' % len(test_df))
# Out:
# # Train set: 2531
# # Test set: 633

# %% [markdown]
# # Trash Bin

# %% [markdown]
# Did that for collaborative filtering, but it seems not fiting for us

# %%
#satisfaction = df_i.iloc[:, [46,98,99]]
#satisfaction
#satisfaction['satisf_level'].value_counts()
