# %% [markdown]
#   ## Libraries

# %%
# IMPORT THESE FIRST.
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.datasets import (make_classification, make_blobs, load_breast_cancer, make_regression, make_friedman1,
                              load_iris)
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import cross_val_score, validation_curve, train_test_split
pd.set_option('display.max_columns', 1000)

# %%
df = pd.read_excel("https://github.com/TechLabs-Berlin/wt21-pet-match/blob/main/data_set/pet-set.xlsx?raw=true")
df.head()
# Out:
#    How old is your cat (years)?  How long have you owned your cat (years)?  \
# 0                             6                                          6
# 1                             2                                          1
# 2                             5                                          5
# 3                             4                                          4
# 4                             3                                          3
#
#   Is your cat male or female? Where did you get your cat from?  \
# 0                        Male           Other (please specify)
# 1                      Female                  Rehoming centre
# 2                        Male                 Friend/neighbour
# 3                      Female                 Friend/neighbour
# 4                      Female           Other (please specify)
#
#                            Other (please specify) Is your cat neutered?  \
# 0                                    Knew his mum                   Yes
# 1                                             NaN                   Yes
# 2                                             NaN                   Yes
# 3                                             NaN                   Yes
# 4  I work at a vet clinic, she was a feral kitten                   Yes
#
#     What breed is your cat? Other (please specify).1  \
# 0  Domestic short/long hair                      NaN
# 1  Domestic short/long hair                      NaN
# 2  Domestic short/long hair                      NaN
# 3  Domestic short/long hair                      NaN
# 4  Domestic short/long hair                      NaN
#
#   Does your cat have access to the outdoors?  \
# 0                                        Yes
# 1                                        Yes
# 2                                         No
# 3                                        Yes
# 4                                        Yes
#
#   If yes, does your cat have constant access, or is this restricted in some way (i.e. the cat is kept in at night or is only let out when someone is home)  \
# 0                                    Constant access
# 1                                  Restricted access
# 2                                                NaN
# 3                                  Restricted access
# 4                                    Constant access
#
#   Does your cat have a litter tray?  \
# 0                                No
# 1                               Yes
# 2                               Yes
# 3                               Yes
# 4                               Yes
#
#   Does your cat have any existing medical conditions?  \
# 0                                                Yes
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   If yes, what condition does he/she suffer from?  \
# 0                                     a bit fluey
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Was this condition present before you acquired your cat?  \
# 0                                                 No
# 1                                                Yes
# 2                                                NaN
# 3                                                 No
# 4                                                NaN
#
#   Does your cat display any behavioural problems  \
# 0                                             No
# 1                                             No
# 2                                             No
# 3                                             No
# 4                                             No
#
#   If yes, what behavioural problem does he/she display?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Was this problem present before you acquired your cat?  \
# 0                                                NaN
# 1                                                 No
# 2                                                NaN
# 3                                                 No
# 4                                                NaN
#
#   Does your cat suffer from a urinary tract infection (e.g. cystitis)?  \
# 0                                              Never
# 1                                              Never
# 2                                               Once
# 3                                              Never
# 4                                              Never
#
#   Does your cat urinate inside the house in a location other than the litter tray?  \
# 0                                              Never
# 1                                              Never
# 2                                               Once
# 3                                       Occasionally
# 4                                       Occasionally
#
#   Does your cat spray urine on any vertical surfaces (e.g. curtains, kitchen, cabinets, doors, walls)?  \
# 0                                              Never
# 1                                              Never
# 2                                              Never
# 3                                              Never
# 4                                              Never
#
#   Does your cat defecate inside the house in a location other than the litter tray?  \
# 0                                              Never
# 1                                               Once
# 2                                               Once
# 3                                              Never
# 4                                       Occasionally
#
#   Does your cat vomit? Does your cat suffer from diarrhoea?  \
# 0                Never                                Never
# 1                Never                                Never
# 2         Occasionally                                 Once
# 3                Often                         Occasionally
# 4                Never                                Never
#
#   Does your cat suffer from constipation?  \
# 0                                   Never
# 1                                   Never
# 2                                   Never
# 3                                   Never
# 4                                   Never
#
#   How would you describe your cat's weight?  \
# 0                                    Normal
# 1                                    Normal
# 2                                Overweight
# 3                                Overweight
# 4                           Very overweight
#
#   What is the condition of your cat's coat (1-poor condition - 5-excellent condition)  \
# 0  4 (e.g. the coat is generally shiny and silky,...
# 1  5 (e.g. the coat is shiny and silky with no ma...
# 2  5 (e.g. the coat is shiny and silky with no ma...
# 3  5 (e.g. the coat is shiny and silky with no ma...
# 4  5 (e.g. the coat is shiny and silky with no ma...
#
#   My cat is keen to explore new things in his/her environment  \
# 0                                            Usually
# 1                                            Usually
# 2                                             Always
# 3                                       Occasionally
# 4                                            Usually
#
#   My cat is playful My cat is vocal when around people  \
# 0           Usually                       Occasionally
# 1           Usually                              Never
# 2      Occasionally                            Usually
# 3           Usually                       Occasionally
# 4      Occasionally                             Always
#
#   My cat behaves aggressively (i.e. growls, hisses, bites, swipes with claws) towards me when I perform routine health procedures (such as grooming/carrying out health checks, or when administering medication, etc.)  \
# 0                                       Occasionally
# 1                                       Occasionally
# 2                                       Occasionally
# 3                                       Occasionally
# 4                                       Occasionally
#
#   My cat tries to avoid me when I try to encourage interactions (i.e. when I call his/her name in a friendly voice, when I make kissing noises, or crouch down and offer it my fingers etc.)  \
# 0                                       Occasionally
# 1                                               Once
# 2                                       Occasionally
# 3                                            Usually
# 4                                       Occasionally
#
#   My cat tries to avoid me when I go to stroke him/her or tickle his/her chin/cheeks  \
# 0                                       Occasionally
# 1                                              Never
# 2                                       Occasionally
# 3                                              Never
# 4                                       Occasionally
#
#   When I initiate contact or interaction with my cat, he/she doesn't move away but it is quiet and not very responsive towards me (i.e. it doesn't purr or rub up against me)  \
# 0                                       Occasionally
# 1                                               Once
# 2                                       Occasionally
# 3                                              Never
# 4                                               Once
#
#   My cat behaves aggressively (i.e. growls, hisses, bites and swipes with claws) towards me when I stroke him/her  \
# 0                                              Never
# 1                                       Occasionally
# 2                                       Occasionally
# 3                                               Once
# 4                                              Never
#
#   My cat will come and say "hello" and approach me (i.e. the cat will approach and make physical contact with me), but will then wander off or move away shortly afterwards rather than staying for a long fuss  \
# 0                                            Usually
# 1                                            Usually
# 2                                            Usually
# 3                                       Occasionally
# 4                                            Usually
#
#   My cat comes and asks me for attention and initiates contact with me (e.g. the cat comes and sits on my knee, or rubs up against me and around me, in order to receive fuss/strokes/chin/cheek tickles)  \
# 0                                       Occasionally
# 1                                             Always
# 2                                       Occasionally
# 3                                             Always
# 4                                             Always
#
#   My cat gets carried away during play, which has led me to being bitten or swiped  \
# 0                                              Never
# 1                                            Usually
# 2                                       Occasionally
# 3                                       Occasionally
# 4                                               Once
#
#   I avoid stroking or handling my cat because I feel that he/she doesn't want me to  \
# 0                                              Never
# 1                                       Occasionally
# 2                                              Never
# 3                                              Never
# 4                                              Never
#
#   I avoid stroking my cat because I think he/she will behave aggressively towards me (i.e. growl, hiss, bite, swipe with claws)  \
# 0                                              Never
# 1                                       Occasionally
# 2                                              Never
# 3                                              Never
# 4                                              Never
#
#   My cat seems angry around me  \
# 0                        Never
# 1                        Never
# 2                 Occasionally
# 3                        Never
# 4                        Never
#
#   My cat is more keen to interact with and be near me when I have food/treats  \
# 0                                            Usually
# 1                                            Usually
# 2                                             Always
# 3                                            Usually
# 4                                       Occasionally
#
#   My cat is comfortable being picked up             My cat is timid  \
# 0                              Disagree  Neither agree nor disagree
# 1                                 Agree  Neither agree nor disagree
# 2                              Disagree                    Disagree
# 3                        Strongly agree                       Agree
# 4                              Disagree  Neither agree nor disagree
#
#   My cat is quick to settle and to adapt to change  \
# 0                       Neither agree nor disagree
# 1                                         Disagree
# 2                                            Agree
# 3                                         Disagree
# 4                                            Agree
#
#   My cat would prefer to be left alone, rather than be with people  \
# 0                                           Disagree
# 1                         Neither agree nor disagree
# 2                         Neither agree nor disagree
# 3                                           Disagree
# 4                         Neither agree nor disagree
#
#    My cat likes being stroked My cat is very tolerant to being handled  \
# 0                       Agree               Neither agree nor disagree
# 1                       Agree               Neither agree nor disagree
# 2  Neither agree nor disagree                                 Disagree
# 3              Strongly agree                                    Agree
# 4                       Agree               Neither agree nor disagree
#
#   If my cat could choose, it would prefer to have a bowl of food rather than interaction with me  \
# 0                                              Agree
# 1                         Neither agree nor disagree
# 2                                              Agree
# 3                         Neither agree nor disagree
# 4                                              Agree
#
#   My cat has negatively changed the way he/she interacts with me since I first acquired him/her (e.g. has become more fearful, behaves aggressively, is less friendly)  \
# 0                                     Strongly agree
# 1                         Neither agree nor disagree
# 2                                           Disagree
# 3                                  Strongly disagree
# 4                                  Strongly disagree
#
#   My cat has positively changed in the way he/she interacts with me since I first acquired him/her (e.g. has become less fearful, behaves less aggressively, is more friendly)  \
# 0                         Neither agree nor disagree
# 1                         Neither agree nor disagree
# 2                                              Agree
# 3                                     Strongly agree
# 4                                     Strongly agree
#
#   My cat behaves differently with strangers than he/she does with me  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                              Agree
# 4                                              Agree
#
#   My cat behaves differently with me than he/she does with other (human) members of the household  \
# 0                                           Disagree
# 1                         Neither agree nor disagree
# 2                         Neither agree nor disagree
# 3                                              Agree
# 4                                              Agree
#
#            My cat is friendly           My cat is fearful  \
# 0                       Agree              Strongly agree
# 1              Strongly agree                    Disagree
# 2  Neither agree nor disagree  Neither agree nor disagree
# 3                       Agree                       Agree
# 4                       Agree  Neither agree nor disagree
#
#   My cat has met all my expectations I am happy with my cat  \
# 0                     Strongly agree         Strongly agree
# 1                     Strongly agree         Strongly agree
# 2         Neither agree nor disagree         Strongly agree
# 3                     Strongly agree         Strongly agree
# 4                     Strongly agree         Strongly agree
#
#   I feel my cat is happy living with me  \
# 0                        Strongly agree
# 1                        Strongly agree
# 2                                 Agree
# 3                        Strongly agree
# 4                        Strongly agree
#
#   I have considered relinquishing or rehoming this cat to someone else  \
# 0                                  Strongly disagree
# 1                                  Strongly disagree
# 2                                  Strongly disagree
# 3                                  Strongly disagree
# 4                                  Strongly disagree
#
#    Gender    Age  \
# 0  Female  25-34
# 1  Female  25-34
# 2  Female  18-24
# 3  Female  18-24
# 4  Female  25-34
#
#    How many other cats live in the household (not including the cat you have described)  \
# 0                                                2.0
# 1                                                0.0
# 2                                                0.0
# 3                                                1.0
# 4                                                3.0
#
#   I see myself as someone who.....  \
# 0                   Agree a little
# 1                   Agree a little
# 2                   Agree a little
# 3                   Agree a little
# 4                Disagree a little
#
#   I see myself as someone who.....Tends to find fault with others  \
# 0                                     Agree a little
# 1                                     Agree a little
# 2                                  Disagree a little
# 3                                     Agree a little
# 4                                     Agree a little
#
#   I see myself as someone who.....Does a thorough job  \
# 0                                     Agree a little
# 1                                     Agree strongly
# 2                                     Agree strongly
# 3                         Neither agree nor disagree
# 4                                     Agree a little
#
#   I see myself as someone who.....Is depressed, blue  \
# 0                                     Agree a little
# 1                                  Disagree a little
# 2                         Neither agree nor disagree
# 3                                     Agree strongly
# 4                                  Disagree a little
#
#   I see myself as someone who.....Is original, comes up with new ideas  \
# 0                                  Disagree a little
# 1                                     Agree a little
# 2                         Neither agree nor disagree
# 3                                     Agree a little
# 4                         Neither agree nor disagree
#
#   I see myself as someone who.....Is reserved  \
# 0                              Agree a little
# 1                              Agree strongly
# 2                           Disagree a little
# 3                              Agree a little
# 4                              Agree a little
#
#   I see myself as someone who.....Is helpful and unselfish with others  \
# 0                                     Agree strongly
# 1                                     Agree a little
# 2                                     Agree a little
# 3                                     Agree a little
# 4                                     Agree a little
#
#   I see myself as someone who.....Can be somewhat careless  \
# 0                                  Disagree a little
# 1                                  Disagree a little
# 2                         Neither agree nor disagree
# 3                                     Agree a little
# 4                         Neither agree nor disagree
#
#   I see myself as someone who.....Is relaxed, handles stress well  \
# 0                                     Agree a little
# 1                                  Disagree a little
# 2                         Neither agree nor disagree
# 3                                  Disagree strongly
# 4                                     Agree a little
#
#   I see myself as someone who.....Is curious about many different things  \
# 0                                     Agree a little
# 1                                     Agree a little
# 2                                     Agree a little
# 3                                     Agree a little
# 4                                     Agree a little
#
#   I see myself as someone who.....Is full of energy  \
# 0                                    Agree a little
# 1                                    Agree a little
# 2                                    Agree a little
# 3                        Neither agree nor disagree
# 4                        Neither agree nor disagree
#
#   I see myself as someone who.....Starts quarrels with others  \
# 0                                  Disagree strongly
# 1                                  Disagree strongly
# 2                         Neither agree nor disagree
# 3                                  Disagree a little
# 4                                  Disagree strongly
#
#   I see myself as someone who.....Is a reliable worker  \
# 0                                     Agree strongly
# 1                                     Agree strongly
# 2                                     Agree strongly
# 3                         Neither agree nor disagree
# 4                                     Agree a little
#
#   I see myself as someone who.....Can be tense  \
# 0                            Disagree a little
# 1                               Agree a little
# 2                               Agree a little
# 3                               Agree strongly
# 4                               Agree a little
#
#   I see myself as someone who.....Is ingenious, a deep thinker  \
# 0                                     Agree strongly
# 1                                     Agree strongly
# 2                         Neither agree nor disagree
# 3                                     Agree strongly
# 4                         Neither agree nor disagree
#
#   I see myself as someone who.....Generates a lot of enthusiasm  \
# 0                                     Agree a little
# 1                                  Disagree a little
# 2                                     Agree a little
# 3                         Neither agree nor disagree
# 4                         Neither agree nor disagree
#
#   I see myself as someone who.....Has a forgiving nature  \
# 0                                     Agree a little
# 1                                     Agree strongly
# 2                                     Agree a little
# 3                                     Agree strongly
# 4                                     Agree a little
#
#   I see myself as someone who.....Tends to be disorganised  \
# 0                                     Agree a little
# 1                                  Disagree strongly
# 2                                  Disagree a little
# 3                                     Agree strongly
# 4                                     Agree a little
#
#   I see myself as someone who.....Worries a lot  \
# 0                                Agree strongly
# 1                                Agree strongly
# 2                                Agree strongly
# 3                                Agree strongly
# 4                                Agree a little
#
#   I see myself as someone who.....Has an active imagination  \
# 0                         Neither agree nor disagree
# 1                                     Agree a little
# 2                                     Agree a little
# 3                                     Agree strongly
# 4                         Neither agree nor disagree
#
#   I see myself as someone who.....Tends to be quiet  \
# 0                                    Agree a little
# 1                                    Agree strongly
# 2                                 Disagree a little
# 3                                    Agree a little
# 4                                    Agree a little
#
#   I see myself as someone who.....Is generally trusting  \
# 0                                     Agree a little
# 1                                     Agree strongly
# 2                                     Agree a little
# 3                                     Agree strongly
# 4                                     Agree a little
#
#   I see myself as someone who… Tends to be lazy  \
# 0                                Agree a little
# 1                             Disagree strongly
# 2                                           NaN
# 3                                Agree a little
# 4                                Agree a little
#
#   I see myself as someone who...Is emotionally stable, not easily upset  \
# 0                                  Disagree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
# 3                                  Disagree strongly
# 4                                     Agree a little
#
#   I see myself as someone who… Is inventive  \
# 0                Neither agree nor disagree
# 1                Neither agree nor disagree
# 2                                       NaN
# 3                            Agree a little
# 4                Neither agree nor disagree
#
#   I see myself as someone who… Has an assertive personality  \
# 0                                  Disagree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
# 3                                  Disagree a little
# 4                         Neither agree nor disagree
#
#   I see myself as someone who… Can be cold or aloof  \
# 0                                 Disagree strongly
# 1                                    Agree a little
# 2                                               NaN
# 3                                    Agree a little
# 4                        Neither agree nor disagree
#
#   I see myself as someone who… Perseveres until the task is finished  \
# 0                                     Agree strongly
# 1                                     Agree a little
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                         Neither agree nor disagree
#
#   i see myself as someone who...Can be moody  \
# 0                             Agree a little
# 1                             Agree a little
# 2                                        NaN
# 3                             Agree strongly
# 4                             Agree a little
#
#   i see myself as someone who...Values artistic, aesthetic experiences  \
# 0                                     Agree strongly
# 1                         Neither agree nor disagree
# 2                                                NaN
# 3                                     Agree strongly
# 4                         Neither agree nor disagree
#
#   i see myself as someone who...Is sometimes shy, inhibited  \
# 0                                     Agree strongly
# 1                                     Agree strongly
# 2                                                NaN
# 3                                     Agree a little
# 4                                     Agree a little
#
#   i see myself as someone who...Is considerate and kind to almost everyone  \
# 0                                     Agree strongly
# 1                                     Agree strongly
# 2                                                NaN
# 3                                     Agree a little
# 4                                     Agree a little
#
#   i see myself as someone who...Does things efficiently  \
# 0                                     Agree a little
# 1                                     Agree strongly
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                     Agree a little
#
#   i see myself as someone who...Remains calm in tense situations  \
# 0                                     Agree a little
# 1                                     Agree strongly
# 2                                                NaN
# 3                                  Disagree a little
# 4                                     Agree a little
#
#   i see myself as someone who...Prefers work that is routine  \
# 0                                  Disagree a little
# 1                                     Agree strongly
# 2                                                NaN
# 3                                     Agree a little
# 4                         Neither agree nor disagree
#
#   i see myself as someone who...Is outgoing, sociable  \
# 0                                     Agree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                         Neither agree nor disagree
#
#   i see myself as someone who...Is sometimes rude to others  \
# 0                                  Disagree strongly
# 1                         Neither agree nor disagree
# 2                                                NaN
# 3                                     Agree a little
# 4                         Neither agree nor disagree
#
#   i see myself as someone who...Makes plans and follows through with them  \
# 0                                  Disagree a little
# 1                                     Agree strongly
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                         Neither agree nor disagree
#
#   i see myself as someone who...Gets easily nervous  \
# 0                                    Agree a little
# 1                                    Agree strongly
# 2                                               NaN
# 3                                    Agree strongly
# 4                                    Agree a little
#
#   i see myself as someone who...Likes to reflect and play with ideas  \
# 0                                  Disagree a little
# 1                                     Agree a little
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                         Neither agree nor disagree
#
#   i see myself as someone who...Has few artistic interests  \
# 0                                  Disagree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                  Disagree a little
#
#   i see myself as someone who...Likes to cooperate with others  \
# 0                                     Agree a little
# 1                         Neither agree nor disagree
# 2                                                NaN
# 3                         Neither agree nor disagree
# 4                                     Agree a little
#
#   i see myself as someone who...Is easily distracted  \
# 0                                     Agree strongly
# 1                                  Disagree strongly
# 2                                                NaN
# 3                                     Agree a little
# 4                                     Agree a little
#
#   i see myself as someone who...Is sophisticated in art, music or literature
# 0                                     Agree a little
# 1                                     Agree strongly
# 2                                                NaN
# 3                                  Disagree strongly
# 4                         Neither agree nor disagree

# %%
df_new = df.rename(columns={"How old is your cat (years)?" : "cat_age","How long have you owned your cat (years)?":"ownership_duration",
                   "Is your cat male or female?":"cat_gender","Where did you get your cat from?":"cat_origin",
                   "Other (please specify)":"other_origin","Is your cat neutered?":"cat_neuter","What breed is your cat?":"cat_breed",
                  "Other (please specify).1":"other_breed","Does your cat have access to the outdoors?":"outdoor_access",
                  "If yes, does your cat have constant access, or is this restricted in some way (i.e. the cat is kept in at night or is only let out when someone is home)":"access_typ",
                  "Does your cat have a litter tray?":"litter_tray","Does your cat have any existing medical conditions?":"medic_cond"}, inplace = True)

# %%
df["cat_origin"].value_counts().plot(kind='bar',title='cat place' ,label= '.')
# Out:
# <AxesSubplot:title={'center':'cat place'}>

# %%
df_breed = df.loc[df["cat_breed"] =="Other (please specify)"]
#df["other_breed"].value_counts()
df_breed["other_breed"].isna().value_counts()
# Out:
# False    620
# Name: other_breed, dtype: int64

# %% [markdown]
# ### variable discribing the satisfaction level in percentage

# %%
# replacing strings with numerical values
df['expectations'] = df['My cat has met all my expectations'].replace({'Strongly agree': 5, 'Agree': 4, 'Neither agree nor disagree': 3, 'Disagree': 2, 'Strongly disagree': 1})
df['happy_owner'] = df['I am happy with my cat'].replace({'Strongly agree': 5, 'Agree': 4, 'Neither agree nor disagree': 3, 'Disagree': 2, 'Strongly disagree': 1})
df['happy_cat'] = df['I feel my cat is happy living with me'].replace({'Strongly agree': 5, 'Agree': 4, 'Neither agree nor disagree': 3, 'Disagree': 2, 'Strongly disagree': 1})
df['rehome'] = df['I have considered relinquishing or rehoming this cat to someone else'].replace({'Strongly agree': 1, 'Agree': 2, 'Neither agree nor disagree': 3, 'Disagree': 4, 'Strongly disagree': 5})

# aggregating final score
df['satisf_level'] = (df['expectations'] + df['happy_owner'] + df['happy_cat'] + df['rehome'])/20

# %%
Satisf_score =df['satisf_level'].value_counts()
#Satisf_score.plot(kind='bar',title='Satisfaction Distribution' ,label= '.')
Satisf_score
# Out:
# 1.00    1940
# 0.95     491
# 0.90     286
# 0.85     250
# 0.80     133
# 0.75      62
# 0.70      38
# 0.65      13
# 0.60      12
# 0.55       8
# 0.40       5
# 0.50       5
# 0.35       2
# 0.45       2
# 0.25       1
# Name: satisf_level, dtype: int64

# %% [markdown]
# ###idea (Hany)
#
# - for training the model we can consider the good match if Satisfaction is 1

# %% [markdown]
# # Owners / Adopters
#
# The aggregarion was made by Hany, all comments also belong to him:)
# Personality traits grouped in five scores according to BFI:
#
# * Extraversion
#
# * Agreeableness
#
# * Conscientiousness
#
# * Neuroticism  (how tense and moody the person )
#
# * Creativity

# %%
# slice with the BFI relevant adopters data
adopters = df.iloc[:, 61:]
# remove the NaN , they are text here
adopters.replace("NaN",np.nan, inplace =True)
adopters.fillna(0,inplace=True)

# lisitng the Reverse questions (take care of the numbering)
rev_col = adopters.iloc[:,[1,5,7,8,11,17,20,22,23,26,30,33,34,36,40,42]]
rev_ques = rev_col.replace({'Agree strongly': 1, 'Agree a little': 2, 'Neither agree nor disagree': 3, 'Disagree a little': 4, 'Disagree strongly': 5})

#listing normal questions 
normal_ques = adopters.drop(columns = rev_col).replace({'Agree strongly': 5, 'Agree a little': 4, 'Neither agree nor disagree': 3, 'Disagree a little': 2, 'Disagree strongly': 1})

# make them into one set, 
adopt_score =  pd.concat([ normal_ques, rev_ques], axis=1)

#adopt_score.head()

# %% [markdown]
# #### note: the code may require some refactoring (working with the bigger set )
# - **used "conctinate instade of inplace= True** : with .replace it gets warning " copy of a slice from a DataFrame" and the inplace is not fully happpening espically when applaying that for the 2nd time

# %% [markdown]
# #### clastering (seems little hard coded, due to the use of concatinate)
#
# - rules (all them are re-aggranged as follows)
# Extraversion:(8 questions) 1, 6R, 11, 16, 21R, 26, 31R, 36
# Agreeableness: (9 questions)2R, 7, 12R, 17, 22, 27R, 32, 37R, 42 ## high no = high agreebleness
# Conscientiousness: (9 questions)3, 8R, 13, 18R, 23R, 28, 33, 38, 43R
# Neuroticism:(8 questions) 4, 9R, 14, 19, 24R, 29, 34R, 39
# Openness: (10 ques )5, 10, 15, 20, 25, 30, 35R, 40, 41R, 44

# %%
# arrange them for better reading.


extraversion = adopt_score.iloc[:,[0,29,6,10,34,16,38,22]]          ##Extraversion

agreeableness = adopt_score.iloc[:,[28,4,32,11,14,37,20,41,26]]     ##Agreeableness

conscientiousness = adopt_score.iloc[:,[1,30,7,33,35,17,21,23,43]]  ##Conscientiousness

neuroticism = adopt_score.iloc[:,[2,31,8,12,36,18,39,24]]          ##Neuroticism  (how tense and moody the person )

creativity = adopt_score.iloc[:,[3,5,9,13,15,19,40,25,42,-1]]      ## openess & creativity


## putting them into columns with precenatges (it can be added to any df )

adopt_score["extraversion"] =extraversion.sum(axis=1)/(len(extraversion.columns)*5)
adopt_score["easy_going"] =agreeableness.sum(axis=1)/(len(agreeableness.columns)*5)
adopt_score["diligent"] =conscientiousness.sum(axis=1)/(len(conscientiousness.columns)*5)
adopt_score["moody_tense"] =neuroticism.sum(axis=1)/(len(neuroticism.columns)*5)
adopt_score["creative"] =creativity.sum(axis=1)/(len(creativity.columns)*5)

adopt_scores_only = adopt_score[["extraversion", "easy_going", "diligent", "moody_tense", "creative"]]

# %%
#adopt_scores_only.head(3)

# %% [markdown]
# # Cats
#
# Grouping cats into 4 personalitiy-Cluster performed by Dayo, I changed it a bit so that we get comparable scores for cats and adopters.
#
# * PC1: Gregariousness (confident, friendly, interactive
#
# * PC: Aggressiveness (agonistic when handled or interacted with)
#
# * PC: Aloofness/avoidance(avoidant of interaction, not friendly
#
# * PC4: Anxiousness/fearfulness (wary of novel/less familiarpeople)

# %%
cats_pc = df.iloc[:, 26 : 54]
# remove the NaN , they are text here
cats_pc.replace("NaN",np.nan, inplace =True)
cats_pc.fillna(0,inplace=True)

# listing the Reverse questions (take care of the numbering)
rev_col_c = cats_pc.iloc[:,[9,16,18,19,20,27]].rename(columns = {"My cat comes and asks me for attention and initiates contact with me (e.g. the cat comes and sits on my knee, or rubs up against me and around me, in order to receive fuss/strokes/chin/cheek tickles)": 'REVERSED My cat comes and asks me for attention and initiates contact with me',
                                          'My cat is timid': 'REVERSED My cat is timid',
                                          'My cat likes being stroked': 'REVERSED My cat likes being stroked',
                                          'My cat is very tolerant to being handled': 'REVERSED My cat is very tolerant to being handled',
                                          'My cat is fearful': 'REVERSED My cat is fearful',
                                          'My cat would prefer to be left alone, rather than be with people': 'REVERSED My cat would prefer to be left alone, rather than be with people'})
rev_ques_c = rev_col_c.replace({'Strongly disagree': 5, 'Never': 5, 'Disagree': 4, 'Once': 4, 'Neither agree nor disagree': 3, 'Occasionally': 3, 'Agree': 2, 'Usually': 2, 'Strongly agree': 1, 'Always': 1})

#listing normal questions 
normal_ques_c = cats_pc.replace({'Strongly disagree': 1, 'Never': 1, 'Disagree': 2, 'Once': 2, 'Neither agree nor disagree': 3, 'Occasionally': 3, 'Agree': 4, 'Usually': 4, 'Strongly agree': 5, 'Always': 5}).drop(columns=cats_pc.iloc[:, [18, 19, 22]])

# make them into one set, 
cats_score =  pd.concat([normal_ques_c, rev_ques_c], axis=1)

# grouping
gregariousness = cats_score.iloc[:,[0,1,2,9,15,17,18,23,24,26,27]] #Gregariousness (confident, friendly, interactive)
aggressiveness = cats_score.iloc[:,[3,7,10,11,12,13,29]] #Aggressiveness (agonistic when handled or interacted with)
avoidance = cats_score.iloc[:,[4,5,6,8,14,19,25,28]] #Aloofness/avoidance(avoidant of interaction, not friendly)
anxiousness = cats_score.iloc[:,[16,20,21,22,24,]] #Anxiousness/fearfulness (wary of novel/less familiarpeople)

# aggregating to percentages
cats_score["friendly"] =gregariousness.sum(axis=1)/(len(gregariousness.columns)*5)
cats_score["agressive"] =aggressiveness.sum(axis=1)/(len(aggressiveness.columns)*5)
cats_score["avoidant"] =avoidance.sum(axis=1)/(len(avoidance.columns)*5)
cats_score["anxious"] =anxiousness.sum(axis=1)/(len(anxiousness.columns)*5)

cats_scores_only = cats_score[["friendly","agressive", "avoidant", "anxious"]]

# %%
df_scores = pd.concat([cats_scores_only, adopt_scores_only, df["satisf_level"]], axis=1)
df_scores.head(3)
# Out:
#    friendly  agressive  avoidant  anxious  extraversion  easy_going  diligent  \
# 0  0.690909   0.314286     0.650     0.68         0.675    0.822222  0.711111
# 1  0.654545   0.571429     0.475     0.60         0.675    0.800000  0.800000
# 2  0.654545   0.514286     0.700     0.64         0.625    0.418889  0.466667
#
#    moody_tense  creative  satisf_level
# 0         0.70      0.64          1.00
# 1         0.75      0.78          1.00
# 2         0.60      0.28          0.85

# %% [markdown]
# # Three datasets with scores only:
#
# * adopt_scores_only: personality scores of potential adopters
# * cats_scores_only: cats' personality scores
# * df_scores: cats' and owners' scores + satisfaction level

# %%
adopt_scores_only.head(5)
# Out:
#    extraversion  easy_going  diligent  moody_tense  creative
# 0         0.675    0.822222  0.711111        0.700      0.64
# 1         0.675    0.800000  0.800000        0.750      0.78
# 2         0.625    0.418889  0.466667        0.600      0.28
# 3         0.575    0.800000  0.577778        0.925      0.72
# 4         0.575    0.733333  0.666667        0.675      0.58

# %%
cats_scores_only.head(5)
# Out:
#    friendly  agressive  avoidant  anxious
# 0  0.690909   0.314286     0.650     0.68
# 1  0.654545   0.571429     0.475     0.60
# 2  0.654545   0.514286     0.700     0.64
# 3  0.727273   0.371429     0.450     0.84
# 4  0.709091   0.342857     0.550     0.76

# %%
df_scores.head(5)
# Out:
#    friendly  agressive  avoidant  anxious  extraversion  easy_going  diligent  \
# 0  0.690909   0.314286     0.650     0.68         0.675    0.822222  0.711111
# 1  0.654545   0.571429     0.475     0.60         0.675    0.800000  0.800000
# 2  0.654545   0.514286     0.700     0.64         0.625    0.418889  0.466667
# 3  0.727273   0.371429     0.450     0.84         0.575    0.800000  0.577778
# 4  0.709091   0.342857     0.550     0.76         0.575    0.733333  0.666667
#
#    moody_tense  creative  satisf_level
# 0        0.700      0.64          1.00
# 1        0.750      0.78          1.00
# 2        0.600      0.28          0.85
# 3        0.925      0.72          1.00
# 4        0.675      0.58          1.00

# %%
df_scores.isna().value_counts()
# Out:
# friendly  agressive  avoidant  anxious  extraversion  easy_going  diligent  moody_tense  creative  satisf_level
# False     False      False     False    False         False       False     False        False     False           3248
#                                                                                                    True              83
# dtype: int64

# %% [markdown]
# # correlation studies

# %%
# Cat behaviour and satisfaction  
data_cat_behaviour = pd.concat([cats_scores_only, df["satisf_level"]], axis=1)
corrMatrix_cat = data_cat_behaviour.corr()


sn.heatmap(corrMatrix_cat,annot= True, ax=plt.axes(), cmap="YlGnBu").set_title("Correlation between cat behaviour data and satisfaction")
plt.gcf().set_size_inches(10, 8)

plt.show()

# %%
# adopter personality and stisfaction 
adopt_personality_data = pd.concat([adopt_scores_only, df["satisf_level"]], axis=1)

corrMatrix_adopt = adopt_personality_data.corr()


sn.heatmap(corrMatrix_adopt,annot= True, ax=plt.axes(), cmap="YlGnBu").set_title("Correlation between adopter personality and satisfaction")
plt.gcf().set_size_inches(10, 8)

plt.show()

# %% [markdown]
# - Notes
# #### 1.Cat Anxiousness is not a strong factor in saisfaction
# #### 2. people like friendly cats (friendly is a very strong indactor of good satisfaction)
# #### 3. there is no obvous correlation between personality and satisfaction ?? (maybe i am wrong)

# %% [markdown]
#  ### experiment(correlation between adopter personality and cat traits)
#  to get a meaningful results : we split the data set to **only include samples with " Satisf_score less than 1"** people with 1 satisifaction feels like they have very inconsistant results

# %%
# data_set new 
df_Match =df_scores.loc[df_scores["satisf_level"] !=1].drop(columns=["satisf_level"])   ## dropped Satisf_score 
# adopter personality and cat traits 

corrMatrix_match = df_Match.corr()
sn.heatmap(corrMatrix_match,annot= True, ax=plt.axes(), cmap="YlGnBu").set_title("Correlation between adopter personality and cat qualities")
plt.gcf().set_size_inches(10, 8)

plt.show()

# %%
#now we have a Dataset to be used for matching using "linar regrssion" 
#there is a correlation between cat persona and human personality socres 
# we need to predict "psersnality_human" with the "breed ":

#to do so i made a quick coorealtion

# %%
#df_match = pd.concat([df_scores, df[["cat_age","ownership_duration","cat_origin","other_origin","cat_neuter","cat_breed","other_breed","outdoor_access"]]], axis=1)
df_match = pd.concat([df_scores, df[["cat_age","ownership_duration","other_breed","Age"]]], axis=1)
dfbreed = df_match.loc[(df["cat_breed"] =="Other (please specify)") & (df["satisf_level"]==1)].fillna(0)

dfbreed
# Out:
#       friendly  agressive  avoidant  anxious  extraversion  easy_going  \
# 5     0.654545   0.314286     0.375     0.56         0.600    0.600000
# 8     0.836364   0.257143     0.275     0.72         0.825    0.844444
# 21    0.690909   0.400000     0.375     0.48         0.650    0.755556
# 31    0.890909   0.200000     0.275     0.52         0.725    0.688889
# 38    0.854545   0.428571     0.350     0.72         0.750    0.733333
# ...        ...        ...       ...      ...           ...         ...
# 3312  0.581818   0.314286     0.575     0.88         0.600    0.666667
# 3320  0.854545   0.200000     0.275     0.68         0.825    0.822222
# 3327  0.781818   0.257143     0.225     0.64         0.700    0.755556
# 3329  0.872727   0.342857     0.300     0.76         0.675    0.733333
# 3330  0.818182   0.257143     0.350     0.44         0.425    0.755556
#
#       diligent  moody_tense  creative  satisf_level  cat_age  \
# 5     0.733333        0.725      0.68           1.0       13
# 8     0.777778        0.675      0.68           1.0       10
# 21    0.888889        0.600      0.72           1.0       17
# 31    0.800000        0.725      0.62           1.0        4
# 38    0.644444        0.900      0.58           1.0       16
# ...        ...          ...       ...           ...      ...
# 3312  0.777778        0.600      0.68           1.0       15
# 3320  0.933333        0.475      0.88           1.0        7
# 3327  0.800000        0.425      0.80           1.0        7
# 3329  0.822222        0.750      0.70           1.0        1
# 3330  0.711111        0.700      0.62           1.0        3
#
#       ownership_duration         other_breed          Age
# 5                     13             siamese        45-54
# 8                     10             Ragdoll        25-34
# 21                    17          Maine Coon        55-64
# 31                     4      Maine coon cat        45-54
# 38                    16  Seal Point Siamese        25-34
# ...                  ...                 ...          ...
# 3312                  15              Bombay  65 and over
# 3320                   7        Ginger Tabby        45-54
# 3327                   7             Ragdoll        45-54
# 3329                   1          Maine Coon        35-44
# 3330                   3         Cornish Rex        25-34
#
# [400 rows x 14 columns]

# %%
dfbreed_matrix = dfbreed.corr()
sn.heatmap(dfbreed_matrix ,annot= True, ax=plt.axes(), cmap="YlGnBu").set_title("Correlation between adopter personality and cat qualities")
plt.gcf().set_size_inches(10, 8)

# %% [markdown]
# #### at stisfaction level == 1 the cat personlity score have no meaning so we can use this to predict the matching breed

# %%
#Satisf_score1 =dfbreed['satisf_level'].value_counts()
#Satisf_score1.plot(kind='bar',title='Satisfaction Distribution' ,label= '.'

# %%
df_match2 = pd.concat([adopt_scores_only, df["other_breed"]], axis=1)

dfbreed_predict = df_match2.loc[(df["cat_breed"] =="Other (please specify)") & (df["satisf_level"]==1)].fillna(0)
dfbreed_predict
# Out:
#       extraversion  easy_going  diligent  moody_tense  creative  \
# 5            0.600    0.600000  0.733333        0.725      0.68
# 8            0.825    0.844444  0.777778        0.675      0.68
# 21           0.650    0.755556  0.888889        0.600      0.72
# 31           0.725    0.688889  0.800000        0.725      0.62
# 38           0.750    0.733333  0.644444        0.900      0.58
# ...            ...         ...       ...          ...       ...
# 3312         0.600    0.666667  0.777778        0.600      0.68
# 3320         0.825    0.822222  0.933333        0.475      0.88
# 3327         0.700    0.755556  0.800000        0.425      0.80
# 3329         0.675    0.733333  0.822222        0.750      0.70
# 3330         0.425    0.755556  0.711111        0.700      0.62
#
#              other_breed
# 5                siamese
# 8                Ragdoll
# 21            Maine Coon
# 31        Maine coon cat
# 38    Seal Point Siamese
# ...                  ...
# 3312              Bombay
# 3320        Ginger Tabby
# 3327             Ragdoll
# 3329          Maine Coon
# 3330         Cornish Rex
#
# [400 rows x 6 columns]

# %%
## clean the breed data 
pd.set_option('display.max_rows', 1000)
dfbreed_predict["other_breed"].value_counts()
# Out:
# Bengal                                                                                                   27
# Siamese                                                                                                  25
# Ragdoll                                                                                                  18
# Burmese                                                                                                  18
# Maine Coon                                                                                               17
# Sphynx                                                                                                   10
# Maine coon                                                                                               10
# Egyptian Mau                                                                                              7
# Abyssinian                                                                                                6
# Birman                                                                                                    6
# Moggy                                                                                                     5
# Russian Blue                                                                                              5
# Siamese                                                                                                   5
# Tabby                                                                                                     5
# Persian                                                                                                   4
# Devon Rex                                                                                                 4
# Burmilla                                                                                                  4
# British Shorthair                                                                                         4
# Somali                                                                                                    4
# Norwegian forest cat                                                                                      4
# Persian                                                                                                   3
# Snowshoe                                                                                                  3
# Tonkinese                                                                                                 3
# siamese                                                                                                   3
# Balinese                                                                                                  3
# sphynx                                                                                                    3
# Ragdoll                                                                                                   3
# Bombay                                                                                                    3
# Norwegian Forest Cat                                                                                      3
# persian                                                                                                   3
# Russian blue                                                                                              2
# ragdoll                                                                                                   2
# British Short Hair                                                                                        2
# British shorthair                                                                                         2
# British Blue                                                                                              2
# Calico                                                                                                    2
# Ocicat                                                                                                    2
# Persian chinchilla                                                                                        2
# Nebelung                                                                                                  2
# Bengal cross                                                                                              2
# Moggie                                                                                                    2
# Oriental shorthair                                                                                        2
# Siberian                                                                                                  2
# British shorthair                                                                                         2
# british shorthair                                                                                         2
# Egyptian mau                                                                                              2
# American Shorthair                                                                                        1
# Silver tabby/Abyssinian cross                                                                             1
# Tortie                                                                                                    1
# Turkish van                                                                                               1
# Tortoiseshell                                                                                             1
# British short hair                                                                                        1
# British blue                                                                                              1
# Part burmese                                                                                              1
# maine coon                                                                                                1
# Devon rex                                                                                                 1
# Stray tabby                                                                                               1
# Ragdoll mix                                                                                               1
# Blue oriental                                                                                             1
# Blue Burmese                                                                                              1
# Turish van                                                                                                1
# Russian white                                                                                             1
# part persian, part moggy                                                                                  1
# Siamese seal point                                                                                        1
# japanese bobtail                                                                                          1
# Maine coon mix                                                                                            1
# Maine coon cat                                                                                            1
# Housecat                                                                                                  1
# Bengal x DSH                                                                                              1
# British blue                                                                                              1
# russian blue                                                                                              1
# EGYPTIAN MAU                                                                                              1
# Oriental red spotted tabby                                                                                1
# Tortoise shell                                                                                            1
# Donskoy                                                                                                   1
# Red Burmese                                                                                               1
# Oriental Shorthair                                                                                        1
# Maine Coon Cross                                                                                          1
# Bengal                                                                                                    1
# Siamese cross                                                                                             1
# minskin                                                                                                   1
# Sphinx Russian blue cross breed                                                                           1
# Lynx mitted ragdoll                                                                                       1
# tabby                                                                                                     1
# Savannah mix                                                                                              1
# Burmilla                                                                                                  1
# moggie                                                                                                    1
# South London black moggie                                                                                 1
# Siamese x                                                                                                 1
# Burmese blue                                                                                              1
# Ginger Tabby                                                                                              1
# DMH                                                                                                       1
# Main coon                                                                                                 1
# Moggy                                                                                                     1
# Short haired ginger                                                                                       1
# Sphynx                                                                                                    1
# Persian X Domestic shorthair                                                                              1
# Maine Coon Cat                                                                                            1
# Savannah                                                                                                  1
# European short hair                                                                                       1
# MAINE COON                                                                                                1
# maine coon / siamese mix                                                                                  1
# Sacred Birman                                                                                             1
# abyssinian                                                                                                1
# Seal Point Siamese                                                                                        1
# Bengal/ragdoll                                                                                            1
# Long haired ginger somali                                                                                 1
# Poss British shorthair or blue x                                                                          1
# Cornish rex                                                                                               1
# devon rex                                                                                                 1
# Oriental Longhair                                                                                         1
# Singapura                                                                                                 1
# Munchkin                                                                                                  1
# Ragdoll X norwegian Forestcat                                                                             1
# Oriental silver tabby cross                                                                               1
# Persian cat                                                                                               1
# Aphrodite                                                                                                 1
# Med hair                                                                                                  1
# British Shorthair                                                                                         1
# Egyptian Mau X                                                                                            1
# Ragdoll/shorthair cross                                                                                   1
# bengal                                                                                                    1
# Maine Coon/Siberian mix                                                                                   1
# LaPerm                                                                                                    1
# Maine coon                                                                                                1
# mixed Turkish Van                                                                                         1
# Canadian Sphynx                                                                                           1
# british blue                                                                                              1
# Thai - Siamese                                                                                            1
# Siamese tabby                                                                                             1
# appears to be russian blue, korat type                                                                    1
# ragdoll mix                                                                                               1
# British Shorthair (Pedigree)                                                                              1
# Persian Bermese                                                                                           1
#  British Short Hairs                                                                                      1
# Bengal Leopard Cat                                                                                        1
# Feral                                                                                                     1
# cornish rex                                                                                               1
# Chinchilla                                                                                                1
# Three quarters oriental (Siamese), one quarter 'moggy'                                                    1
# Tonkineses                                                                                                1
# blue russian in appearance                                                                                1
# calico tortoishell                                                                                        1
# Half Siamese                                                                                              1
# Asian                                                                                                     1
# Ragdoll and Devon Rex                                                                                     1
# burmese                                                                                                   1
# Selkirk Rex                                                                                               1
# Mix of Maine Coon, Norwegian forest cat and domestic (she has long hair and is black, white and red))     1
# Siamese X tonkens                                                                                         1
# SPHYNX                                                                                                    1
# Part domestic, part siamese                                                                               1
# Bombay mix                                                                                                1
# Abysinian cross                                                                                           1
# maine coone                                                                                               1
# Havana brown oriental                                                                                     1
# Half Ragdoll and Half Tabby                                                                               1
# Seal Point Siamese                                                                                        1
# Oriental longhair and Balinese                                                                            1
# persian x                                                                                                 1
# F1 Hybrid - ALC / Bengal                                                                                  1
# Short hair exotic                                                                                         1
# Maine Coone                                                                                               1
# vet suspects a Burmese mix                                                                                1
# ginger and white                                                                                          1
# European                                                                                                  1
# tonkinese                                                                                                 1
# Sphyinx                                                                                                   1
# "farm mix"                                                                                                1
# Burmeese                                                                                                  1
# Part Burmese                                                                                              1
# short hair persian blue                                                                                   1
# shorthaired exotic                                                                                        1
# Turkish van                                                                                               1
# Part Norwegian forest cat                                                                                 1
# Birmin                                                                                                    1
# Cornish Rex                                                                                               1
# Old English tortoise-shell                                                                                1
# longhair                                                                                                  1
# Persian blue                                                                                              1
# Moggy. Tabby                                                                                              1
# British Shorthair Blue                                                                                    1
# Ginger                                                                                                    1
# Tabbythe Maine clone cross                                                                                1
# Lilac Burmese                                                                                             1
# Burmese                                                                                                   1
# Sphynx (domestic)                                                                                         1
# BSH X ?                                                                                                   1
# we're told he's part Siamese mixed with domestic shorthair                                                1
# Oriental                                                                                                  1
# He's not any fancy breed, just a beautiful black moggy                                                    1
# siamese/moggy mix                                                                                         1
# Tuxedo                                                                                                    1
# European (ex) stray                                                                                       1
# Neva Masquerade                                                                                           1
# Domestic semi long hair                                                                                   1
# Name: other_breed, dtype: int64

# %% [markdown]
# # Clustering KNN (breed prediction )

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from matplotlib import cm

# %% [markdown]
# X - adopt_scores_only

# %%
x_people = dfbreed_predict[['extraversion', 'easy_going', 'diligent', 'moody_tense','creative']]
y_cats = dfbreed_predict["other_breed"]

# %%
X_train, X_test, y_train, y_test = train_test_split(x_people, y_cats, random_state=0)

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
# we must apply the scaling to the test set that we computed for the training set
X_test_scaled = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors = 15)
knn.fit(X_train_scaled, y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train_scaled, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test_scaled, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.13
# Accuracy of K-NN classifier on test set: 0.05

# %% [markdown]
# ### Seems that it is a wrong  direction

# %%
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
