# %%
###Correlation of certain attributes to "My cat has met all my expectations" (Satisfaction)
        ###Basic Data###
    
#df["How old is your cat (years)?"].corr(df["My cat has met all my expectations"]) = 0.04307976484563097
#df["Age"].corr(df["My cat has met all my expectations"]) = -0.006850388661670585
#df["How long have you owned your cat (years)?"].corr(df["My cat has met all my expectations"]) = 0.061180697260684785
#df["How would you describe your cat's weight?"].corr(df["My cat has met all my expectations"]) = -0.0460786957621361


        ###Behaviour###

#df["My cat behaves aggressively (i.e. growls, hisses, bites and swipes with claws) towards me when I stroke him/her"].corr(df["My cat has met all my expectations"]) = -0.23239282855063673
#df["My cat behaves aggressively (i.e. growls, hisses, bites, swipes with claws) towards me when I perform routine health procedures (such as grooming/carrying out health checks, or when administering medication, etc.)"].corr(df["My cat has met all my expectations"]) = -0.20382161585398914
#df["Does your cat urinate inside the house in a location other than the litter tray?"].corr(df["My cat has met all my expectations"]) = 0.16919238198200726
#df["Does your cat display any behavioural problems"].corr(df["My cat has met all my expectations"]) = 0.16919238198200726
#df["My cat tries to avoid me when I try to encourage interactions (i.e. when I call his/her name in a friendly voice, when I make kissing noises, or crouch down and offer it my fingers etc.)"].corr(df["My cat has met all my expectations"]) = -0.23279754989792173

        ###Medical Issues
#df["Does your cat vomit?"].corr(df["My cat has met all my expectations"]) = 0.010614900555367797
#df["Does your cat suffer from diarrhoea?"].corr(df["My cat has met all my expectations"]) = 0.016550768817678342
#

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from scipy import stats

# %%
df= pd.read_excel("data_set\pet-set.xlsx")
pd.set_option("display.max_columns", 120)
pd.set_option("display.max_rows", 120)
df.head(2)
# Out:
#    How old is your cat (years)?  How long have you owned your cat (years)?  \
# 0                             6                                          6
# 1                             2                                          1
#
#   Is your cat male or female? Where did you get your cat from?  \
# 0                        Male           Other (please specify)
# 1                      Female                  Rehoming centre
#
#   Other (please specify) Is your cat neutered?   What breed is your cat?  \
# 0           Knew his mum                   Yes  Domestic short/long hair
# 1                    NaN                   Yes  Domestic short/long hair
#
#   Other (please specify).1 Does your cat have access to the outdoors?  \
# 0                      NaN                                        Yes
# 1                      NaN                                        Yes
#
#   If yes, does your cat have constant access, or is this restricted in some way (i.e. the cat is kept in at night or is only let out when someone is home)  \
# 0                                    Constant access
# 1                                  Restricted access
#
#   Does your cat have a litter tray?  \
# 0                                No
# 1                               Yes
#
#   Does your cat have any existing medical conditions?  \
# 0                                                Yes
# 1                                                 No
#
#   If yes, what condition does he/she suffer from?  \
# 0                                     a bit fluey
# 1                                             NaN
#
#   Was this condition present before you acquired your cat?  \
# 0                                                 No
# 1                                                Yes
#
#   Does your cat display any behavioural problems  \
# 0                                             No
# 1                                             No
#
#   If yes, what behavioural problem does he/she display?  \
# 0                                                NaN
# 1                                                NaN
#
#   Was this problem present before you acquired your cat?  \
# 0                                                NaN
# 1                                                 No
#
#   Does your cat suffer from a urinary tract infection (e.g. cystitis)?  \
# 0                                              Never
# 1                                              Never
#
#   Does your cat urinate inside the house in a location other than the litter tray?  \
# 0                                              Never
# 1                                              Never
#
#   Does your cat spray urine on any vertical surfaces (e.g. curtains, kitchen, cabinets, doors, walls)?  \
# 0                                              Never
# 1                                              Never
#
#   Does your cat defecate inside the house in a location other than the litter tray?  \
# 0                                              Never
# 1                                               Once
#
#   Does your cat vomit? Does your cat suffer from diarrhoea?  \
# 0                Never                                Never
# 1                Never                                Never
#
#   Does your cat suffer from constipation?  \
# 0                                   Never
# 1                                   Never
#
#   How would you describe your cat's weight?  \
# 0                                    Normal
# 1                                    Normal
#
#   What is the condition of your cat's coat (1-poor condition - 5-excellent condition)  \
# 0  4 (e.g. the coat is generally shiny and silky,...
# 1  5 (e.g. the coat is shiny and silky with no ma...
#
#   My cat is keen to explore new things in his/her environment  \
# 0                                            Usually
# 1                                            Usually
#
#   My cat is playful My cat is vocal when around people  \
# 0           Usually                       Occasionally
# 1           Usually                              Never
#
#   My cat behaves aggressively (i.e. growls, hisses, bites, swipes with claws) towards me when I perform routine health procedures (such as grooming/carrying out health checks, or when administering medication, etc.)  \
# 0                                       Occasionally
# 1                                       Occasionally
#
#   My cat tries to avoid me when I try to encourage interactions (i.e. when I call his/her name in a friendly voice, when I make kissing noises, or crouch down and offer it my fingers etc.)  \
# 0                                       Occasionally
# 1                                               Once
#
#   My cat tries to avoid me when I go to stroke him/her or tickle his/her chin/cheeks  \
# 0                                       Occasionally
# 1                                              Never
#
#   When I initiate contact or interaction with my cat, he/she doesn't move away but it is quiet and not very responsive towards me (i.e. it doesn't purr or rub up against me)  \
# 0                                       Occasionally
# 1                                               Once
#
#   My cat behaves aggressively (i.e. growls, hisses, bites and swipes with claws) towards me when I stroke him/her  \
# 0                                              Never
# 1                                       Occasionally
#
#   My cat will come and say "hello" and approach me (i.e. the cat will approach and make physical contact with me), but will then wander off or move away shortly afterwards rather than staying for a long fuss  \
# 0                                            Usually
# 1                                            Usually
#
#   My cat comes and asks me for attention and initiates contact with me (e.g. the cat comes and sits on my knee, or rubs up against me and around me, in order to receive fuss/strokes/chin/cheek tickles)  \
# 0                                       Occasionally
# 1                                             Always
#
#   My cat gets carried away during play, which has led me to being bitten or swiped  \
# 0                                              Never
# 1                                            Usually
#
#   I avoid stroking or handling my cat because I feel that he/she doesn't want me to  \
# 0                                              Never
# 1                                       Occasionally
#
#   I avoid stroking my cat because I think he/she will behave aggressively towards me (i.e. growl, hiss, bite, swipe with claws)  \
# 0                                              Never
# 1                                       Occasionally
#
#   My cat seems angry around me  \
# 0                        Never
# 1                        Never
#
#   My cat is more keen to interact with and be near me when I have food/treats  \
# 0                                            Usually
# 1                                            Usually
#
#   My cat is comfortable being picked up             My cat is timid  \
# 0                              Disagree  Neither agree nor disagree
# 1                                 Agree  Neither agree nor disagree
#
#   My cat is quick to settle and to adapt to change  \
# 0                       Neither agree nor disagree
# 1                                         Disagree
#
#   My cat would prefer to be left alone, rather than be with people  \
# 0                                           Disagree
# 1                         Neither agree nor disagree
#
#   My cat likes being stroked My cat is very tolerant to being handled  \
# 0                      Agree               Neither agree nor disagree
# 1                      Agree               Neither agree nor disagree
#
#   If my cat could choose, it would prefer to have a bowl of food rather than interaction with me  \
# 0                                              Agree
# 1                         Neither agree nor disagree
#
#   My cat has negatively changed the way he/she interacts with me since I first acquired him/her (e.g. has become more fearful, behaves aggressively, is less friendly)  \
# 0                                     Strongly agree
# 1                         Neither agree nor disagree
#
#   My cat has positively changed in the way he/she interacts with me since I first acquired him/her (e.g. has become less fearful, behaves less aggressively, is more friendly)  \
# 0                         Neither agree nor disagree
# 1                         Neither agree nor disagree
#
#   My cat behaves differently with strangers than he/she does with me  \
# 0                                              Agree
# 1                                              Agree
#
#   My cat behaves differently with me than he/she does with other (human) members of the household  \
# 0                                           Disagree
# 1                         Neither agree nor disagree
#
#   My cat is friendly My cat is fearful My cat has met all my expectations  \
# 0              Agree    Strongly agree                     Strongly agree
# 1     Strongly agree          Disagree                     Strongly agree
#
#   I am happy with my cat I feel my cat is happy living with me  \
# 0         Strongly agree                        Strongly agree
# 1         Strongly agree                        Strongly agree
#
#   I have considered relinquishing or rehoming this cat to someone else  \
# 0                                  Strongly disagree
# 1                                  Strongly disagree
#
#    Gender    Age  \
# 0  Female  25-34
# 1  Female  25-34
#
#    How many other cats live in the household (not including the cat you have described)  \
# 0                                                2.0
# 1                                                0.0
#
#   I see myself as someone who.....  \
# 0                   Agree a little
# 1                   Agree a little
#
#   I see myself as someone who.....Tends to find fault with others  \
# 0                                     Agree a little
# 1                                     Agree a little
#
#   I see myself as someone who.....Does a thorough job  \
# 0                                     Agree a little
# 1                                     Agree strongly
#
#   I see myself as someone who.....Is depressed, blue  \
# 0                                     Agree a little
# 1                                  Disagree a little
#
#   I see myself as someone who.....Is original, comes up with new ideas  \
# 0                                  Disagree a little
# 1                                     Agree a little
#
#   I see myself as someone who.....Is reserved  \
# 0                              Agree a little
# 1                              Agree strongly
#
#   I see myself as someone who.....Is helpful and unselfish with others  \
# 0                                     Agree strongly
# 1                                     Agree a little
#
#   I see myself as someone who.....Can be somewhat careless  \
# 0                                  Disagree a little
# 1                                  Disagree a little
#
#   I see myself as someone who.....Is relaxed, handles stress well  \
# 0                                     Agree a little
# 1                                  Disagree a little
#
#   I see myself as someone who.....Is curious about many different things  \
# 0                                     Agree a little
# 1                                     Agree a little
#
#   I see myself as someone who.....Is full of energy  \
# 0                                    Agree a little
# 1                                    Agree a little
#
#   I see myself as someone who.....Starts quarrels with others  \
# 0                                  Disagree strongly
# 1                                  Disagree strongly
#
#   I see myself as someone who.....Is a reliable worker  \
# 0                                     Agree strongly
# 1                                     Agree strongly
#
#   I see myself as someone who.....Can be tense  \
# 0                            Disagree a little
# 1                               Agree a little
#
#   I see myself as someone who.....Is ingenious, a deep thinker  \
# 0                                     Agree strongly
# 1                                     Agree strongly
#
#   I see myself as someone who.....Generates a lot of enthusiasm  \
# 0                                     Agree a little
# 1                                  Disagree a little
#
#   I see myself as someone who.....Has a forgiving nature  \
# 0                                     Agree a little
# 1                                     Agree strongly
#
#   I see myself as someone who.....Tends to be disorganised  \
# 0                                     Agree a little
# 1                                  Disagree strongly
#
#   I see myself as someone who.....Worries a lot  \
# 0                                Agree strongly
# 1                                Agree strongly
#
#   I see myself as someone who.....Has an active imagination  \
# 0                         Neither agree nor disagree
# 1                                     Agree a little
#
#   I see myself as someone who.....Tends to be quiet  \
# 0                                    Agree a little
# 1                                    Agree strongly
#
#   I see myself as someone who.....Is generally trusting  \
# 0                                     Agree a little
# 1                                     Agree strongly
#
#   I see myself as someone who… Tends to be lazy  \
# 0                                Agree a little
# 1                             Disagree strongly
#
#   I see myself as someone who...Is emotionally stable, not easily upset  \
# 0                                  Disagree a little
# 1                         Neither agree nor disagree
#
#   I see myself as someone who… Is inventive  \
# 0                Neither agree nor disagree
# 1                Neither agree nor disagree
#
#   I see myself as someone who… Has an assertive personality  \
# 0                                  Disagree a little
# 1                         Neither agree nor disagree
#
#   I see myself as someone who… Can be cold or aloof  \
# 0                                 Disagree strongly
# 1                                    Agree a little
#
#   I see myself as someone who… Perseveres until the task is finished  \
# 0                                     Agree strongly
# 1                                     Agree a little
#
#   i see myself as someone who...Can be moody  \
# 0                             Agree a little
# 1                             Agree a little
#
#   i see myself as someone who...Values artistic, aesthetic experiences  \
# 0                                     Agree strongly
# 1                         Neither agree nor disagree
#
#   i see myself as someone who...Is sometimes shy, inhibited  \
# 0                                     Agree strongly
# 1                                     Agree strongly
#
#   i see myself as someone who...Is considerate and kind to almost everyone  \
# 0                                     Agree strongly
# 1                                     Agree strongly
#
#   i see myself as someone who...Does things efficiently  \
# 0                                     Agree a little
# 1                                     Agree strongly
#
#   i see myself as someone who...Remains calm in tense situations  \
# 0                                     Agree a little
# 1                                     Agree strongly
#
#   i see myself as someone who...Prefers work that is routine  \
# 0                                  Disagree a little
# 1                                     Agree strongly
#
#   i see myself as someone who...Is outgoing, sociable  \
# 0                                     Agree a little
# 1                         Neither agree nor disagree
#
#   i see myself as someone who...Is sometimes rude to others  \
# 0                                  Disagree strongly
# 1                         Neither agree nor disagree
#
#   i see myself as someone who...Makes plans and follows through with them  \
# 0                                  Disagree a little
# 1                                     Agree strongly
#
#   i see myself as someone who...Gets easily nervous  \
# 0                                    Agree a little
# 1                                    Agree strongly
#
#   i see myself as someone who...Likes to reflect and play with ideas  \
# 0                                  Disagree a little
# 1                                     Agree a little
#
#   i see myself as someone who...Has few artistic interests  \
# 0                                  Disagree a little
# 1                         Neither agree nor disagree
#
#   i see myself as someone who...Likes to cooperate with others  \
# 0                                     Agree a little
# 1                         Neither agree nor disagree
#
#   i see myself as someone who...Is easily distracted  \
# 0                                     Agree strongly
# 1                                  Disagree strongly
#
#   i see myself as someone who...Is sophisticated in art, music or literature
# 0                                     Agree a little
# 1                                     Agree strongly

# %%
df.shape
# Out:
# (3331, 105)

# %%
###General Statistics Data Description ###
df.dropna().describe()

#df["How old is your cat (years)?"].corr(df["My cat has met all my expectations"])= 0.04307976484563097
# Out:
#        How old is your cat (years)?  \
# count                     10.000000
# mean                      12.000000
# std                        4.690416
# min                        2.000000
# 25%                       10.500000
# 50%                       12.000000
# 75%                       14.750000
# max                       19.000000
#
#        How long have you owned your cat (years)?  \
# count                                  10.000000
# mean                                   10.800000
# std                                     3.823901
# min                                     2.000000
# 25%                                    10.000000
# 50%                                    11.500000
# 75%                                    12.750000
# max                                    16.000000
#
#        How many other cats live in the household (not including the cat you have described)
# count                                          10.000000
# mean                                            1.000000
# std                                             1.333333
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.500000
# 75%                                             1.750000
# max                                             4.000000

# %%
df["I am happy with my cat"].value_counts()
# Out:
# 5.0    2794
# 4.0     395
# 3.0      39
# 2.0      16
# 1.0       4
# Name: I am happy with my cat, dtype: int64

# %%
### Changed the string data into numeric data  >>> float64
        ###Basic Data of cat
df["I am happy with my cat"].replace({"Strongly agree": 5, "Agree": 4, "Neither agree nor disagree": 3, "Disagree": 2, "Strongly disagree": 1}, inplace= True)
df["My cat has met all my expectations"].replace({"Strongly agree": 5, "Agree": 4, "Neither agree nor disagree": 3, "Disagree": 2, "Strongly disagree": 1}, inplace= True)


df["Is your cat male or female?"].replace({"Male":1, "Female":2},inplace= True)


        ###Behaviour of cat
df["My cat behaves aggressively (i.e. growls, hisses, bites and swipes with claws) towards me when I stroke him/her"].replace({"Never": 1, "Occasionally": 2, "Once": 3, "Usually": 4, "Always": 5}, inplace= True)
df["My cat behaves aggressively (i.e. growls, hisses, bites, swipes with claws) towards me when I perform routine health procedures (such as grooming/carrying out health checks, or when administering medication, etc.)"].replace({"Never": 1, "Occasionally": 2, "Once": 3, "Usually": 4, "Always": 5}, inplace= True)
df["Does your cat urinate inside the house in a location other than the litter tray?"].replace({"Never": 1, "Occasionally": 2, "Once": 3, "Often": 4, "Always": 5}, inplace= True)
df["Does your cat display any behavioural problems"].replace({"Yes": 1, "No": 2}, inplace= True)
df["My cat tries to avoid me when I try to encourage interactions (i.e. when I call his/her name in a friendly voice, when I make kissing noises, or crouch down and offer it my fingers etc.)"].replace({"Never": 1, "Occasionally": 2, "Once": 3, "Usually": 4, "Always": 5}, inplace= True)
df["Does your cat defecate inside the house in a location other than the litter tray?"].replace({"Never": 1, "Occasionally": 2, "Once": 3, "Often": 4, "Always": 5}, inplace= True)
df["My cat is friendly"].replace({"Strongly agree": 5, "Agree": 4, "Neither agree nor disagree": 3, "Disagree": 2, "Strongly disagree": 1}, inplace= True)


        ###Medical condition of cat
df["Does your cat vomit?"].replace({"Never": 1, "Occasionally": 2, "Once": 3, "Often": 4, "Always": 5}, inplace= True)
df["Does your cat suffer from diarrhoea?"].replace({"Never": 1, "Occasionally": 2, "Once": 3, "Often": 4, "Always": 5}, inplace= True)
df["How would you describe your cat's weight?"].replace({ "Very underweight": 1, "Underweight": 2, "Normal": 3, "Overweight": 4, "Very overweight": 5}, inplace= True)
df["Does your cat suffer from constipation?"].replace({"Never": 1, "Occasionally": 2, "Once": 3, "Often": 4, "Always": 5}, inplace= True)
df["What is the condition of your cat's coat (1-poor condition - 5-excellent condition)"].replace({"5 (e.g. the coat is shiny and silky with no mats or bald patches)": 5, "4 (e.g. the coat is generally shiny and silky, but can occasionally be a bit dirty or greasy, but there are no mats or bald patches)": 4, "3 (e.g. the coat is slightly dirty and/or greasy, and/or a few mats and/or a few bald patches)": 3, "2 (e.g. the coat is generally quite dirty, and/or greasy, and/or several mats and/or several bald patches)": 2, "1 (e.g. the coat is very dirty and/or greasy, and/or lots of mats and/or lots of bald patches)": 1},inplace= True)


        ###Personality of cat owner
df["Age"].replace({"18-24": 1, "25-34": 2, "35-44": 3, "45-54": 4, "55-64": 5, "65 and over": 6}, inplace= True)
df["Gender"].replace({"Male": 1, "Female": 2, "Prefer not to say": 3}, inplace= True)
df["I see myself as someone who.....Tends to find fault with others"].replace({"Disagree strongly": 5, "Disagree a little": 4, "Neither agree nor disagree": 3, "Agree a little":2, "Agree strongly":1}, inplace= True)
df["I see myself as someone who.....Does a thorough job"].replace({"Disagree strongly": 1, "Disagree a little": 2, "Neither agree nor disagree": 3, "Agree a little":4, "Agree strongly":5}, inplace= True)
df["I see myself as someone who.....Is depressed, blue"].replace({"Disagree strongly": 5, "Disagree a little": 4, "Neither agree nor disagree": 3, "Agree a little":2, "Agree strongly":1}, inplace= True)
df["I see myself as someone who.....Is relaxed, handles stress well"].replace({"Disagree strongly": 1, "Disagree a little": 2, "Neither agree nor disagree": 3, "Agree a little":4, "Agree strongly":5}, inplace= True)
df["I see myself as someone who… Tends to be lazy"].replace({"Disagree strongly": 5, "Disagree a little": 4, "Neither agree nor disagree": 3, "Agree a little":2, "Agree strongly":1}, inplace= True)

# %%
### recheck if the datatype changed accordingly
df["My cat tries to avoid me when I try to encourage interactions (i.e. when I call his/her name in a friendly voice, when I make kissing noises, or crouch down and offer it my fingers etc.)"].dtype
# Out:
# dtype('int64')

# %%
###Test
pd.to_numeric(df["Age"], errors= "raise")
# Out:
# 0       2.0
# 1       2.0
# 2       1.0
# 3       1.0
# 4       2.0
#        ...
# 3326    5.0
# 3327    4.0
# 3328    1.0
# 3329    3.0
# 3330    2.0
# Name: Age, Length: 3331, dtype: float64

# %%
### There is no correlation between age of the cat and the satisfaction of the owner 
df["How old is your cat (years)?"].corr(df["My cat has met all my expectations"])
### There is no correlation between age of the owner and the satisfaction of the owner 
df["Age"].corr(df["My cat has met all my expectations"])
### There is no  correlation between the the years a pet owner owns a catand the satisfaction
df["How long have you owned your cat (years)?"].corr(df["My cat has met all my expectations"])
### There is a slight correlation between the aggressiveness of a cat and the owner satisfaction
df["My cat behaves aggressively (i.e. growls, hisses, bites and swipes with claws) towards me when I stroke him/her"].corr(df["My cat has met all my expectations"])
### There is no  correlation between the behavioural problems of a pet and  the satisfaction of a pet owner
df["Does your cat display any behavioural problems"].corr(df["My cat has met all my expectations"])
### There is no correlation between if the cat urinates inside the house and the satisfaction of the owner
df["Does your cat urinate inside the house in a location other than the litter tray?"].corr(df["My cat has met all my expectations"])
### There is no correlation between if the cat vomits and the satisfaction of the owner
df["Does your cat vomit?"].corr(df["My cat has met all my expectations"])
### There is no correlation between if the cat suffers from diarrhoea and the owners satisfaction
df["Does your cat suffer from diarrhoea?"].corr(df["My cat has met all my expectations"])
### There is no correlation between the weight of the cat and the satisfaction of the owner
df["How would you describe your cat's weight?"].corr(df["My cat has met all my expectations"])
### There is only a slight correlation between the interaction level and the satisfaction of the owner
df["My cat tries to avoid me when I try to encourage interactions (i.e. when I call his/her name in a friendly voice, when I make kissing noises, or crouch down and offer it my fingers etc.)"].corr(df["My cat has met all my expectations"])
### There is a slight correlation between the aggressiveness of a cat and the owner satisfaction
df["My cat behaves aggressively (i.e. growls, hisses, bites, swipes with claws) towards me when I perform routine health procedures (such as grooming/carrying out health checks, or when administering medication, etc.)"].corr(df["My cat has met all my expectations"])
# Out:
# -0.20382161585398914

# %%
data_cat_basic = {'SF0': df["My cat has met all my expectations"],
        'SF1': df["I am happy with my cat"],
        'A': df["How long have you owned your cat (years)?"],
        'B': df["How would you describe your cat's weight?"],
        'C': df["How old is your cat (years)?"],
        'D': df["Is your cat male or female?"],
        }

# creation of new DataFrame
df1 = pd.DataFrame(data_cat_basic,columns= ["SF0","SF1","A","B","C","D"])
df1.corr()
# Out:
#           SF0       SF1         A         B         C         D
# SF0  1.000000  0.550786  0.061181 -0.046079  0.043080 -0.016808
# SF1  0.550786  1.000000  0.024187  0.002473  0.018152 -0.007295
# A    0.061181  0.024187  1.000000 -0.115521  0.882036  0.027222
# B   -0.046079  0.002473 -0.115521  1.000000 -0.105212 -0.027958
# C    0.043080  0.018152  0.882036 -0.105212  1.000000  0.039809
# D   -0.016808 -0.007295  0.027222 -0.027958  0.039809  1.000000

# %%
corrMatrix1 = df1.corr()
ax=plt.axes()
sns.heatmap(corrMatrix1,annot= True, ax=ax, cmap="YlGnBu")
ax.set_title("Correlation between basic cat data and satisfaction")
plt.gcf().set_size_inches(10, 8)

plt.show()

# %%
data_cat_behaviour = {'SF0': df["My cat has met all my expectations"],
        'SF1': df["I am happy with my cat"],
        'A': df["My cat behaves aggressively (i.e. growls, hisses, bites and swipes with claws) towards me when I stroke him/her"],
        'B': df["My cat behaves aggressively (i.e. growls, hisses, bites, swipes with claws) towards me when I perform routine health procedures (such as grooming/carrying out health checks, or when administering medication, etc.)"],
        'C': df["Does your cat urinate inside the house in a location other than the litter tray?"],
        'D': df["Does your cat display any behavioural problems"],
        'E': df["My cat tries to avoid me when I try to encourage interactions (i.e. when I call his/her name in a friendly voice, when I make kissing noises, or crouch down and offer it my fingers etc.)"],
        'F': df["Does your cat defecate inside the house in a location other than the litter tray?"],
        'G': df["My cat is friendly"]
        }

# creation of new DataFrame
df2 = pd.DataFrame(data_cat_behaviour,columns= ["SF0","SF1","A","B","C","D","E","F","G"])
df2.corr()
# Out:
#           SF0       SF1         A         B         C         D         E  \
# SF0  1.000000  0.550786 -0.232393 -0.203822 -0.050796  0.169192 -0.232798
# SF1  0.550786  1.000000 -0.207109 -0.180648 -0.060491  0.198269 -0.186685
# A   -0.232393 -0.207109  1.000000  0.368462  0.013331 -0.145142  0.278170
# B   -0.203822 -0.180648  0.368462  1.000000  0.028189 -0.134721  0.222158
# C   -0.050796 -0.060491  0.013331  0.028189  1.000000 -0.151324  0.023906
# D    0.169192  0.198269 -0.145142 -0.134721 -0.151324  1.000000 -0.078056
# E   -0.232798 -0.186685  0.278170  0.222158  0.023906 -0.078056  1.000000
# F   -0.050412 -0.040855  0.040358  0.048181  0.272913 -0.088530  0.041817
# G    0.393427  0.333712 -0.267269 -0.283134 -0.052360  0.183347 -0.266685
#
#             F         G
# SF0 -0.050412  0.393427
# SF1 -0.040855  0.333712
# A    0.040358 -0.267269
# B    0.048181 -0.283134
# C    0.272913 -0.052360
# D   -0.088530  0.183347
# E    0.041817 -0.266685
# F    1.000000 -0.044517
# G   -0.044517  1.000000

# %%
corrMatrix2 = df2.corr()
ax=plt.axes()
sns.heatmap(corrMatrix2,annot= True, ax=ax, cmap="YlGnBu")
ax.set_title("Correlation between cat behaviour data and satisfaction")
plt.gcf().set_size_inches(10, 8)

plt.show()

# %%
data_cat_medical = {'SF0': df["My cat has met all my expectations"],
        'SF1': df["I am happy with my cat"],
        'B': df["Does your cat vomit?"],
        'C': df["Does your cat suffer from diarrhoea?"],
        'D': df["How would you describe your cat's weight?"],
        'E': df["What is the condition of your cat's coat (1-poor condition - 5-excellent condition)"],
        'F': df["Does your cat suffer from constipation?"],
        'G': df["Does your cat defecate inside the house in a location other than the litter tray?"]
        }

# creation of new DataFrame
df3 = pd.DataFrame(data_cat_medical,columns= ["SF0","SF1","A","B","C","D","E","F","G"])
df3.corr()
# Out:
#           SF0       SF1         B         C         D         E         F  \
# SF0  1.000000  0.550786  0.010615  0.016551 -0.046079  0.056707  0.006117
# SF1  0.550786  1.000000  0.023848  0.041559  0.002473  0.062680  0.041972
# B    0.010615  0.023848  1.000000  0.139644 -0.019892 -0.069521  0.125020
# C    0.016551  0.041559  0.139644  1.000000 -0.034612 -0.070464  0.166886
# D   -0.046079  0.002473 -0.019892 -0.034612  1.000000  0.088663 -0.041119
# E    0.056707  0.062680 -0.069521 -0.070464  0.088663  1.000000 -0.108991
# F    0.006117  0.041972  0.125020  0.166886 -0.041119 -0.108991  1.000000
# G   -0.050412 -0.040855  0.078133  0.135839 -0.049240 -0.078514  0.101932
#
#             G
# SF0 -0.050412
# SF1 -0.040855
# B    0.078133
# C    0.135839
# D   -0.049240
# E   -0.078514
# F    0.101932
# G    1.000000

# %%
corrMatrix3 = df3.corr()
ax=plt.axes()
sns.heatmap(corrMatrix3,annot= True, ax=ax, cmap="YlGnBu")
ax.set_title("Correlation between cat medical condition data and satisfaction")
plt.gcf().set_size_inches(10, 8)

plt.show()

# %%
data_cat_owner = {'SF0': df["My cat has met all my expectations"],
        'SF1': df["I am happy with my cat"],
        'A': df["Age"],
        'B': df["Gender"],
        'C': df["How many other cats live in the household (not including the cat you have described)"],
        'D': df["I see myself as someone who.....Tends to find fault with others"],
        'E': df["I see myself as someone who.....Does a thorough job"],
        'F': df["I see myself as someone who.....Is depressed, blue"],
        'G': df["I see myself as someone who.....Is relaxed, handles stress well"],
        'G': df["I see myself as someone who… Tends to be lazy"]
        }

# creation of new DataFrame
df4 = pd.DataFrame(data_cat_owner,columns= ["SF0","SF1","A","B","C","D","E","F","G","H"])
df4.corr()
# Out:
#           SF0       SF1         A         B         C         D         E  \
# SF0  1.000000  0.550786 -0.006850 -0.019424  0.098168  0.029434  0.082613
# SF1  0.550786  1.000000 -0.025093  0.009097  0.084303  0.011165  0.055815
# A   -0.006850 -0.025093  1.000000 -0.057613  0.089186  0.116784 -0.006787
# B   -0.019424  0.009097 -0.057613  1.000000  0.051599  0.034364  0.050296
# C    0.098168  0.084303  0.089186  0.051599  1.000000  0.032641 -0.009136
# D    0.029434  0.011165  0.116784  0.034364  0.032641  1.000000  0.001982
# E    0.082613  0.055815 -0.006787  0.050296 -0.009136  0.001982  1.000000
# F    0.011497  0.008830  0.094854 -0.004106 -0.030065  0.206577  0.131028
# G    0.040514  0.021641  0.151879  0.040696  0.027724  0.151837  0.311512
#
#             F         G
# SF0  0.011497  0.040514
# SF1  0.008830  0.021641
# A    0.094854  0.151879
# B   -0.004106  0.040696
# C   -0.030065  0.027724
# D    0.206577  0.151837
# E    0.131028  0.311512
# F    1.000000  0.244371
# G    0.244371  1.000000

# %%
corrMatrix4 = df4.corr()
ax=plt.axes()
sns.heatmap(corrMatrix4,annot= True, ax=ax, cmap="YlGnBu")
ax.set_title("Correlation between cat owner data and satisfaction")
plt.gcf().set_size_inches(10, 8)

plt.show()
